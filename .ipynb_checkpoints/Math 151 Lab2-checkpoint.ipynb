# %%
# Lab 2
import sympy as sp
import sympy.plotting as spp


#Part 1
t = sp.Symbol('t')
f = (1-sp.exp(-t))/(1+sp.exp(-t))
graph = spp.plot_parametric(t,f,(t,-5,5),Ylim = [-5,5])
# part a
print("This fuction passes the horasontal line test")

# part b
f2 = -sp.ln((1+x)/(-x+1))
graph2 = spp.plot_parametric(t,f2,(t,-5,5),Ylim = [-5,5])

# part C
print("it is the inverse")
# part d
# Out:
# This fuction passes the horasontal line test
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sympy\plotting\experimental_lambdify.py in __call__(self, args, kwargs)
#     194             #The result can be sympy.Float. Hence wrap it with complex type.
# --> 195             result = complex(self.lambda_func(args))
#     196             if abs(result.imag) > 1e-7 * abs(result):
#
# ~\Anaconda3\lib\site-packages\sympy\plotting\experimental_lambdify.py in __call__(self, *args, **kwargs)
#     316     def __call__(self, *args, **kwargs):
# --> 317         return self.lambda_func(*args, **kwargs)
#     318
#
# <string> in <lambda>(x0)
#
# ~\Anaconda3\lib\site-packages\sympy\core\expr.py in __complex__(self)
#     284         re, im = result.as_real_imag()
# --> 285         return complex(float(re), float(im))
#     286
#
# ...

# %%
# Part 2
x = sp.Symbol('x')
f = (sp.log(x)-sp.log(7))/(x-7)
leftval = (f.subs({x:i}).evalf() for i in (6.9,6.99,6.99))
sp.plot(f,(x,6,8))

# %%
# part 3
