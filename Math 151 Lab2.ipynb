# %%
# Lab 2
import sympy as sp
import sympy.plotting as spp


#Part 1
t = sp.Symbol('t')
f = (1-sp.exp(-t))/(1+sp.exp(-t))
graph = spp.plot_parametric(t,f,(t,-5,5),Ylim = [-5,5])
# part a
print("This fuction passes the horasontal line test")

# part b
f2 = -sp.ln((1+t)/(-t+1))
graph2 = spp.plot_parametric(t,f2,(t,-5,5),Ylim = [-5,5])

# part C
print("it is the inverse")
# part d
# Out:
# This fuction passes the horasontal line test
# it is the inverse

# %%
# Part 2
x = sp.Symbol('x')
f = (sp.log(x)-sp.log(7))/(x-7)
print ("\nleftval\n\n")
leftval = [print(f.subs({x:i}).evalf()) for i in (6.9,6.99,6.99)]  
print("\nrightval\n\n")
rightval = [print(f.subs({x:i}).evalf()) for i in (7.1,7.01,7.001)]
sp.plot(f,(x,6,8))
# Out:
# leftval
#
#
# 0.143887374520997
# 0.142959280959450
# 0.142959280959450
#
# rightval
#
#
# 0.141846349919564
# 0.142755199118535
# 0.142846939747252

# %%
# part 3

x = sp.Symbol('x')
f = (sp.sin(sp.pi/x))
right = [print(f.subs({x:i}).evalf()) for i in (7.1,7.01,7.001)]
# Out:
# 0.428179983740455
# 0.433306825866043
# 0.433825981636691
