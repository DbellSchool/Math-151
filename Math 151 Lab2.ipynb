# %%
# Lab 2
# David Bell
#
#
import sympy as sp
import sympy.plotting as spp


#Part 1
# defines Variabel
t = sp.Symbol('t')
              
# defines function
f = (1-sp.exp(-t))/(1+sp.exp(-t))

# part A

#prints passes virticle line test
print("Part A\n This fuction passes the horasontal line test")
# uses sympy.plotting to plot the funtion
graph = spp.plot_parametric(t,f,(t,-5,5),Ylim = [-5,5])

# part b

print("Part B")
# creates invers graph by switching the funciton(y) val and the x val
graph2 = spp.plot_parametric(f,t,(t,-5,5),Ylim = [-5,5])

# part C
# no idea whaat this does 
f2Print = spp.plot_parametric(f,t,(t,-5,5),Ylim = [-5,5],show = False)
print("Part C \nit is the inverse")

# adds the two graphs together
graph.extend(graph2)
# shows the graph
graph.show()


# part d

# declares another symbole to use in inverse function
y = sp.Symbol('y')
# solves for the inverse
f1_inv = sp.solve(y-f1,t)
print("Part D\n\n",f1_inv)
# Out:
# Part A
#  This fuction passes the horasontal line test
# Part B
# Part C
# it is the inverse
# Part D
#
#  [log(-(y + 1)/(y - 1))]

# %%
# Part 2

# declares a variable
x = sp.Symbol('x')
#declares a funtion
f = (sp.log(x)-sp.log(7))/(x-7)

# part a
print ("\nPart A \n  leftval\n\n")
# solves values for a function lim from the left 
leftval = [print(f.subs({x:i}).evalf()) for i in (6.9,6.99,6.99)]  
print("\n  rightval\n\n")
# solves values for a function lim from the right
rightval = [print(f.subs({x:i}).evalf()) for i in (7.1,7.01,7.001)]

# part b

print("\nPart B")
# plots the function using sympy
sp.plot(f,(x,6,8))

# part c

# finds the limit using Sympy (function, variable, at ?)
L = sp.limit(f,x,7) # 1/7
print("Part C\n",L)
# Out:
# Part A
#   leftval
#
#
# 0.143887374520997
# 0.142959280959450
# 0.142959280959450
#
#   rightval
#
#
# 0.141846349919564
# 0.142755199118535
# 0.142846939747252
#
# Part B
# Part C
#  1/7

# %%
# part 3

# declares new function
f = (sp.sin(sp.pi/x))

print ("\nPart a\nx = 0.1, 0.01, 0.001, 0.0001 \n\n")
# evaluates funciton for items in for loop  (0.1, 0.01, 0.001, 0.0001)
right = [print(f.subs({x:i}).evalf()) for i in (0.1, 0.01, 0.001, 0.0001)]

print ("\nx = −0.1, −0.01, −0.001, −0.0001 \n\n")
# evaluates funciton for items in for loop (#−0.1, −0.01, −0.001, −0.0001)
rightval = [print(f.subs({x:i}).evalf()) for i in (-0.1, -0.01, -0.001, -0.0001)]

print ("\nPart b\nx = 0.15, 0.015, 0.0015, 0.00015 \n\n")
##evaluates funciton for items in for loop ( 0.15, 0.015, 0.0015, 0.00015,)
rightval = [print(f.subs({x:i}).evalf()) for i in (0.15, 0.015, 0.0015, 0.00015)]
##evaluates funciton for items in for loop ( -0.15, -0.015, -0.0015, -0.00015,)
print ("\nx = -0.15, -0.015, -0.0015, -0.00015  \n\n")
rightval = [print(f.subs({x:i}).evalf()) for i in (-0.15, -0.015, -0.0015, -0.00015 )]

print("\nPart c")
#plots points of graph usind sympy plott
sp.plot(f,(x,-1, 1))
print("This means that the limit doese not exist, because 0 does not = 0.86")
# Out:
# Part a
# x = 0.1, 0.01, 0.001, 0.0001
#
#
# 0
# 0
# 0
# 0
#
# x = −0.1, −0.01, −0.001, −0.0001
#
#
# 0
# 0
# 0
# 0
#
# Part b
# x = 0.15, 0.015, 0.0015, 0.00015
#
#
# 0.866025403784438
# 0.866025403784431
# 0.866025403784498
# 0.866025403783962
#
# x = -0.15, -0.015, -0.0015, -0.00015
#
#
# -0.866025403784438
# -0.866025403784431
# -0.866025403784498
# -0.866025403783962
#
# Part c
# This means that the limit doese not exist, because 0 does not = 0.86
